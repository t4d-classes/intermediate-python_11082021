# %% [markdown]
# # Exercise #5

# %% [markdown]
# Step 1. Load the cities (not the swapped version) CSV file created in exercise 4. Use only the city for the index. You can modify the cities.csv file with Excel to only have the first 10 rows.

# %%
# Step 1 Solution

import pandas as pd

cities = pd.read_csv("cities_top10.csv", index_col=0)

# %% [markdown]
# Step 2. Use head to display the first three rows.

# %%
# Step 2 Solution

cities.head(3)
# Out:
#                     State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# New York City    New York      8175133        8253213                   301.5
# Los Angeles    California      3792621        3970219                   468.7
# Chicago          Illinois      2695598        2677643                   227.3
#
#                Population Change  Population Density 2010  \
# City
# New York City           0.955091             27114.868990
# Los Angeles             4.682725              8091.787924
# Chicago                -0.666086             11859.208100
#
#                Population Density 2020
# City
# New York City             27373.840800
# Los Angeles                8470.704075
# Chicago                   11780.215570

# %% [markdown]
# Step 3. Use tail to display the last three rows.

# %%
# Step 3 Solution

cities.tail(3)
# Out:
#                 State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# San Diego  California      1307402        1422420                   325.2
# Dallas          Texas      1197816        1343266                   340.9
# San Jose   California       945942        1013616                   177.5
#
#            Population Change  Population Density 2010  Population Density 2020
# City
# San Diego           8.797447              4020.301353              4373.985240
# Dallas             12.142933              3513.687298              3940.352009
# San Jose            7.154138              5329.250704              5710.512676

# %% [markdown]
# Step 4. Display the row for Phoenix using the label. Hint: take a look at "loc" attribute.

# %%
# Step 4 Solution

# type(cities.loc[ "Phoenix" ])

cities.loc[ ["Phoenix"] ]
# Out:
#            State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# Phoenix  Arizona      1445632        1708127                   517.6
#
#          Population Change  Population Density 2010  Population Density 2020
# City
# Phoenix          18.157802              2792.952087              3300.090804

# %% [markdown]
# Step 5. Display the row for Phoenix using the row index. Hint: take a look at "iloc" attribute.

# %%
# Step 5 Solution

# cities.iloc[ [5] ]

display(cities.index.get_loc("Phoenix"))

cities.iloc[ [ cities.index.get_loc("Phoenix") ] ]
# Out:
# 5
#            State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# Phoenix  Arizona      1445632        1708127                   517.6
#
#          Population Change  Population Density 2010  Population Density 2020
# City
# Phoenix          18.157802              2792.952087              3300.090804

# %% [markdown]
# Step 6. How many cities experienced negative growth from 2010 to 2020?

# %%
# Step 6 Solution

cities[cities["Population Change"] < 0]
# Out:
#             State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# Chicago  Illinois      2695598        2677643                   227.3
#
#          Population Change  Population Density 2010  Population Density 2020
# City
# Chicago          -0.666086               11859.2081              11780.21557

# %% [markdown]
# Step 7. Display Chicago to Houston using a range of labels.

# %%
# Step 7 Solution

cities[ "Chicago":"Houston" ]
# Out:
#             State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# Chicago  Illinois      2695598        2677643                   227.3
# Houston     Texas      2100263        2316120                   637.5
#
#          Population Change  Population Density 2010  Population Density 2020
# City
# Chicago          -0.666086             11859.208100             11780.215570
# Houston          10.277618              3294.530196              3633.129412

# %% [markdown]
# Step 8. Display Chicago to Houston using a range of indexes. Hint: take a look at "iloc" attribute.

# %%
# Step 8 Solution

cities.iloc[2:4]
# Out:
#             State  2010 Actual  2020 Estimate  2016 Land Area (sq mi)  \
# City
# Chicago  Illinois      2695598        2677643                   227.3
# Houston     Texas      2100263        2316120                   637.5
#
#          Population Change  Population Density 2010  Population Density 2020
# City
# Chicago          -0.666086             11859.208100             11780.215570
# Houston          10.277618              3294.530196              3633.129412

# %% [markdown]
# Step 9. Display descriptive statistics for the data frame.

# %%
# Step 9 Solution

cities.describe()
# Out:
#         2010 Actual  2020 Estimate  2016 Land Area (sq mi)  Population Change  \
# count  1.000000e+01   1.000000e+01               10.000000          10.000000
# mean   2.451382e+06   2.585023e+06              359.140000           8.299937
# std    2.186342e+06   2.168183e+06              160.122378           6.529397
# min    9.459420e+05   1.013616e+06              134.200000          -0.666086
# 25%    1.312403e+06   1.458594e+06              245.850000           3.750012
# 50%    1.485819e+06   1.643307e+06              333.050000           7.975793
# 75%    2.546764e+06   2.587262e+06              466.775000          11.676605
# max    8.175133e+06   8.253213e+06              637.500000          18.157802
#
#        Population Density 2010  Population Density 2020
# count                10.000000                10.000000
# mean               8026.712710              8374.441708
# std                7529.281296              7452.100220
# min                2792.952087              3300.090804
# 25%                3349.319471              3709.935061
# 50%                4674.776029              5042.248958
# 75%               10551.296461             10939.324676
# max               27114.868990             27373.840800

# %% [markdown]
# Step 10. Use a pie chart to show the 2020 estimated population of the first 10 cities relative to the other cities in the data frame.

# %%
# Step 10 Solution

from matplotlib import pyplot as plt
# %matplotlib inline

fig_1 = plt.figure(1, figsize=(10, 10), facecolor="white")

ax1 = fig_1.add_subplot(111)

ax1.pie(
  cities["2020 Estimate"].values,
  labels=cities.index.values,
  autopct='%1.1f%%',
)

ax1.axis('equal')


plt.show()
